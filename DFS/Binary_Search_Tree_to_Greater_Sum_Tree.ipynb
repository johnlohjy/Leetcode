# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    
    value = 0

    def bstToGst(self, root):
        """
        :type root: TreeNode
        :rtype: TreeNode
        """

        """
        Naive way:
        Get a list of the nodes from smallest to largest 
        all the way left, root, all the way right
        In order traversal

        in_order = []

        def inorder(node):
            if node:
                inorder(node.left)
                in_order.append(node.val)
                inorder(node.right)

        Go in inorder again to change the values
        
        Better way:
        Go all the way right, root, all the way left and accumulate the value along the way
        """
        
        def reverse_inorder_traversal(node):
            if node:
                reverse_inorder_traversal(node.right)
                self.value+=node.val
                node.val=self.value
                reverse_inorder_traversal(node.left)
                
        reverse_inorder_traversal(root)
        
        return root

        """
        In order Traversal
        def inorder_traversal(node,in_order):
            if node:
                inorder_traversal(node.left,in_order)
                in_order.append(node.val)
                inorder_traversal(node.right,in_order)

        in_order = []
        inorder_traversal(root, in_order)
        print(in_order)
        for i in range(len(in_order)):
            in_order[i] = sum(in_order[i:])
        print(in_order)
        inorder_traversal_changeval(root,in_order,0)

        return root
        """
