# %%
class Solution(object):
    def minFallingPathSum(self, matrix):
        """
        :type matrix: List[List[int]]
        :rtype: int
        """

        """
        matrix nxn
        Return min sum of falling path through matrix

        Falling path:
        - Start at any element in the first row
        - Choose the element in the next row that is directly below or diagnonally
          left or right:
          - (row+1,col-1), (row+1,col), (row+1,col+1)

        DP
        1. Bottom up
        What are things we need to build up
        What is the base case
        2. Top Down
        What is the sub-problem/recurrence relation for top down
        What is the base case

        What are the overlapping problems we can use memoization to avoid

        Top-down DP problem

        Sub-problem/reccurence relation:
        dp[r][c] = min(dp[r+1][c-1], dp[r+1][c], dp[r+1][c+1])

        Base case: r==len(matrix)

        use a memo to store the minimum sum of reaching that cell from the bottom
        """

        memo = [[None for __ in range(len(matrix[0]))] for _ in range(len(matrix))]

        def top_down(r,c,matrix,memo):
            if r < len(matrix):
                if r < 0 or r > len(matrix)-1 or c < 0 or c > len(matrix[0])-1:
                    return 100000
                if memo[r][c]==None:
                    memo[r][c] = matrix[r][c] + min(top_down(r+1,c-1,matrix,memo), top_down(r+1,c,matrix,memo), top_down(r+1,c+1,matrix,memo))
                return memo[r][c]
            return 0

        
        res = []
        for c in range(len(matrix[0])):
            res.append(top_down(0,c,matrix,memo))
        return min(res)
